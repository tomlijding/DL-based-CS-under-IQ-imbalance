# %%
import os
import sys
cwd_dir = os.path.split(os.getcwd())[0]
if cwd_dir not in sys.path:
    sys.path.append(cwd_dir)
# Out:
# c:\Users\tomli\Documents\S_C\Year 1\Semester 3\Data Compression\Projects\Main Project
